# %%
import pandas as pd

# %%
csv_path = "../raw data/IMDB_ratings.csv"
df_ratings = pd.read_csv(csv_path)
df_ratings.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes  mean_vote  median_vote  \
# 0     tt0000009                    5.9          154        5.9          6.0
# 1     tt0000574                    6.1          589        6.3          6.0
# 2     tt0001892                    5.8          188        6.0          6.0
# 3     tt0002101                    5.2          446        5.3          5.0
# 4     tt0002130                    7.0         2237        6.9          7.0
#
#    votes_10  votes_9  votes_8  votes_7  votes_6  ...  females_30age_avg_vote  \
# 0        12        4       10       43       28  ...                     5.7
# 1        57       18       58      137      139  ...                     6.2
# 2         6        6       17       44       52  ...                     5.8
# 3        15        8       16       62       98  ...                     5.5
# 4       210      225      436      641      344  ...                     7.3
#
# ...

# %%
csv_path3 = "../data/movies.csv"
df_movies = pd.read_csv(csv_path3)
df_movies.head()
# Out:
#   imdb_title_id                                              title  year  \
# 0     tt0000009                                         Miss Jerry  1894
# 1     tt0002101                                          Cleopatra  1912
# 2     tt0002199  From the Manger to the Cross; or, Jesus of Naz...  1912
# 3     tt0003643  The Avenging Conscience: or 'Thou Shalt Not Kill'  1914
# 4     tt0003657                                        The Bargain  1914
#
#        genre  duration country language            director  \
# 0    Romance        45     USA     None     Alexander Black
# 1      Drama       100     USA  English  Charles L. Gaskill
# 2  Biography        60     USA  English       Sidney Olcott
# 3      Crime        78     USA  English       D.W. Griffith
# 4    Western        70     USA  English     Reginald Barker
#
#                 writer               production_company  \
# 0      Alexander Black       Alexander Black Photoplays
# ...

# %%
new_df = df_ratings.set_index('imdb_title_id').join(df_movies.set_index('imdb_title_id'))

# %%
new_df.head()
# Out:
#                weighted_average_vote  total_votes  mean_vote  median_vote  \
# imdb_title_id
# tt0000009                        5.9          154        5.9          6.0
# tt0000574                        6.1          589        6.3          6.0
# tt0001892                        5.8          188        6.0          6.0
# tt0002101                        5.2          446        5.3          5.0
# tt0002130                        7.0         2237        6.9          7.0
#
#                votes_10  votes_9  votes_8  votes_7  votes_6  votes_5  ...  \
# imdb_title_id                                                         ...
# tt0000009            12        4       10       43       28       28  ...
# tt0000574            57       18       58      137      139      103  ...
# tt0001892             6        6       17       44       52       32  ...
# tt0002101            15        8       16       62       98      117  ...
# ...

# %%
new_df.count()
# Out:
# weighted_average_vote    85855
# total_votes              85855
# mean_vote                85855
# median_vote              85855
# votes_10                 85855
#                          ...
# reviews_from_users       25083
# reviews_from_critics     25083
# month_published          25083
# genre_2                  19160
# genre_3                  11156
# Length: 66, dtype: int64

# %%
new_df.to_csv('moviesandratings.csv', index=True)
